# %% [markdown]
# # **ASSIGNEMENT #006**
#
# # **COVID-19 Virus Spread Live Dashboard Application**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import folium as flm

# %%
dataset1 = pd.read_csv('../assets/covid19/dataset1.csv')
dataset2 = pd.read_csv('../assets/covid19/dataset2.csv')
dataset3 = pd.read_csv('../assets/covid19/dataset3.csv')

# %%
dataset2[["Country_Region","Lat","Long_"]][dataset2["Country_Region"] == "Turkey"]
# Out:
#     Country_Region      Lat    Long_
# 176         Turkey  38.9637  35.2433

# %%
wmap = flm.Map(location=[38.9637, 35.2433])
flm.Marker([38.9637, 35.2433], popup='<i>Kayseri near Yozgat</i>', tooltip="Kayseri").add_to(wmap)
flm.CircleMarker(
    location=[38.9637, 35.2433],
    radius=100,
    popup='Kayseri',
    color='#DC143C',
    fill=True,
    fill_color='#DC143C'
).add_to(wmap)
wmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
covidmap = flm.Map(location=[38.9637, 35.2433],tiles='Stamen Toner')

# %%
flm.Marker([38.9637, 35.2433], popup='<i>Kayseri near Yozgat</i>', tooltip="Kayseri").add_to(covidmap)
covidmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Finding the top 15 infected countries

# %%
def find_top_confirmed(dataset,n = 15):
    countries = dataset.groupby('Country_Region',as_index=False).sum()[['Country_Region','Confirmed', 'Deaths', 'Recovered', 'Active']]
    cdf = countries.nlargest(n, 'Confirmed')[['Country_Region','Confirmed']]
    cdf.index = [i for i in range(n)]
    return cdf.rename(columns={'Country_Region':'Countries'})

# %%
cdf = find_top_confirmed(dataset2)
cdf
# Out:
#          Countries  Confirmed
# 0               US  3804907.0
# 1           Brazil  2098389.0
# 2            India  1118206.0
# 3           Russia   776212.0
# 4             Peru   369429.0
# 5     South Africa   364328.0
# 6           Mexico   349396.0
# 7            Chile   330930.0
# 8   United Kingdom   296944.0
# 9             Iran   276202.0
# 10        Pakistan   265083.0
# 11           Spain   264836.0
# 12    Saudi Arabia   253349.0
# 13           Italy   244624.0
# 14          Turkey   220572.0

# %%
confirmed_cases = [(country,confirmed) for country,confirmed in zip(cdf.index,cdf['Confirmed'])]

# %%
confirmed_cases
# Out:
# [('US', 3804907.0),
#  ('Brazil', 2098389.0),
#  ('India', 1118206.0),
#  ('Russia', 776212.0),
#  ('Peru', 369429.0),
#  ('South Africa', 364328.0),
#  ('Mexico', 349396.0),
#  ('Chile', 330930.0),
#  ('United Kingdom', 296944.0),
#  ('Iran', 276202.0),
#  ('Pakistan', 265083.0),
#  ('Spain', 264836.0),
#  ('Saudi Arabia', 253349.0),
#  ('Italy', 244624.0),
#  ('Turkey', 220572.0)]

# %%
data = dataset2[['Lat','Long_','Confirmed']]
data = data.dropna()

# %%
def circle_maker(x,m):
    flm.Circle(location=[x[0],x[1]], radius=float(x[2]), color="red",
                  popup='confirmed cases:{}'.format(x[2])).add_to(m)

# %%
data.apply(lambda x:circle_maker(x,covidmap),axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 183    None
# 184    None
# 185    None
# 186    None
# 187    None
# Length: 186, dtype: object

# %%
covidmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
