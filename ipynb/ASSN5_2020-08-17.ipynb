# %% [markdown]
# # **ASSIGNEMENT #005**
#
# # **COVID-19 Virus Spread Data Vizualization**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset1 = pd.read_csv('../assets/covid19/dataset1.csv')
dataset2 = pd.read_csv('../assets/covid19/dataset2.csv')
dataset3 = pd.read_csv('../assets/covid19/dataset3.csv')

# %% [markdown]
# ## Dataset #1 Plot

# %%
dataset1.plot()
# Out:
# <AxesSubplot:>

# %%
dataset1["FIPS"].plot(color='c')
# Out:
# <AxesSubplot:>

# %%
dataset1["Confirmed"].plot(color='m')
# Out:
# <AxesSubplot:>

# %%
dataset1["Recovered"].plot()
# Out:
# <AxesSubplot:>

# %%
dataset1["Deaths"].plot(color='r',marker='+')
# Out:
# <AxesSubplot:>

# %%
dataset1["Active"].plot(color='g',marker='*')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Dataset #2

# %%
dataset2.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Dataset #3

# %%
dataset3.plot()
# Out:
# <AxesSubplot:>
